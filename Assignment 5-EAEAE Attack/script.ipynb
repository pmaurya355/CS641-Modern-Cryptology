# %%
import paramiko
import time

hostname = "172.27.26.188"
port = 22
username = "student"
password = "cs641"

ssh = paramiko.client.SSHClient()
ssh.load_system_host_keys()
ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
ssh.connect(hostname, port, username, password, allow_agent=False, look_for_keys=False)

chan = ssh.invoke_shell()

# %%
chan.send("PriSoN\n")
time.sleep(1)
chan.recv(5000)
time.sleep(1)
chan.send("PriSoN\n")
time.sleep(1)
chan.recv(5000)
time.sleep(1)
chan.send("5\n")
time.sleep(1)
chan.recv(5000)
time.sleep(1)
chan.send("go\n")
time.sleep(1)
chan.recv(5000)
time.sleep(1)
chan.send("wave\n")
time.sleep(1)
chan.recv(5000)
time.sleep(1)
chan.send("dive\n")
time.sleep(1)
chan.recv(5000)
time.sleep(1)
chan.send("go\n")
time.sleep(1)
chan.recv(5000)
time.sleep(1)
chan.send("read\n")
time.sleep(1)
chan.recv(5000)
# Out:
# b'read\r\n\x1b[H\x1b[J\r\n\r\n\r\n\r\n\tYou come up to the closed door and look at the screen ...\r\n\t... there is nothing written on it as earlier.\r\n\r\n\tAs you wonder if the spirit is around to help you out, you hear\r\n\tit whispering in your ears ...\r\n\r\n\t"This is another magical screen. And this one I remember perfectly...\r\n\t\r\n\tConsider a block of size 8 bytes as 8 x 1 vector over F_{128} --\r\n\tconstructed using the degree 7 irreducible polynomial x^7 + x + 1\r\n\tover F_2. Define two transformations: first a linear transformation \r\n\tgiven by invertible 8 x 8 key matrix A with elements from F_{128} and \r\n\tsecond an exponentiation given by 8 x 1 vector E whose elements are \r\n\tnumbers between 1 and 126. E is applied on a block by taking the ith \r\n\telement of the block and raising it to the power given by ith element in E.\r\n\r\n\tApply these transformations in the sequence EAEAE on the input block\r\n\tto obtain the output block. Both E and A are part 
# ...

# %%
chan.send("password\n")
time.sleep(1)
chan.recv(5000)
# Out:
# b'password\r\n\x1b[H\x1b[J\r\n\r\n\r\n\r\n\r\nSlowly, a new text starts appearing on the screen. It reads ...\r\n\t\tgsmgfnhmhtjtmqksmoihgoiujifqhghk\r\n\r\n\r\nPress c to continue> '

# %%
password1 = 'gsmgfnhmhtjtmqks'
password2 = 'moihgoiujifqhghk'
chan.send("c\n")
time.sleep(1)
chan.recv(5000)
# Out:
# b'c\r\n\x1b[H\x1b[J\r\n\r\n\r\n\r\n\tThe text in the screen vanishes!\r\n\r\n> '

# %%
file1 = open('plain_texts.txt', 'r')
Lines = file1.readlines()
out = []
for line in Lines:
    inpf=''
    for inp in line.split():
        chan.send(inp+"\n")
        time.sleep(1)
        x = chan.recv(5000)
        x = x[-43:-27]
        print(inp,x)
        inpf += ' '+x.decode("UTF-8")
        chan.send("c\n")
        time.sleep(1)
        chan.recv(5000)
    out.append(inpf[1:])

file = open("cipher_texts.txt","w")
for i in out:
    file.write(i)
    file.write("\n")
file.close()
# Out:
# ffffffffffffffff b'ffffffffffffffff'
# fgffffffffffffff b'jijtkrgijoifgqip'
# fhffffffffffffff b'fklrknmtmifthikt'
# fiffffffffffffff b'jljojugfmthmkqir'
# fjffffffffffffff b'fplfigkgjgkmkrho'
# fkffffffffffffff b'jofjlmmsmogtfpjm'
# flffffffffffffff b'fuggkjluhgmmgomp'
# fmffffffffffffff b'jrkugihpioffinms'
# fnffffffffffffff b'gjjqkujrihhijqjq'
# foffffffffffffff b'kmgmiihggginhgkm'
# fpffffffffffffff b'ggjlhjkfjsmmlfgj'
# fqffffffffffffff b'khfojimtmqkqlmjh'
# frffffffffffffff b'gthqlghmiqjmfpmk'
# fsffffffffffffff b'ksfhifltjskrkgfo'
# ftffffffffffffff b'gqiphogsgqhqismp'
# fuffffffffffffff b'knflmohufghrfmjf'
# gfffffffffffffff b'hnlggqlmluhpmlki'
# ggffffffffffffff b'lqmqjhfmmlfqkjig'
# ghffffffffffffff b'hskkkfgsiphshpiu'
# giffffffffffffff b'lthiluijlpkhmgkt'
# gjffffffffffffff b'hhlkmkkuighpmjfi'
# gkffffffffffffff b'lgmmfrhnjpkqfllh'
# glffffffffffffff b'hmhjlfkklqluhojf'
# gmffffffffffffff b'ljhqmjipiglmfikh'
# gnffffffffffffff b'irmrlkjkltgqmtfo'
# ...
